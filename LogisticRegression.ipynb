# %% [markdown]
# <a href="https://colab.research.google.com/github/saifulislamsarfaraz/Machine-Learning/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('marital status.csv')

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     NaN
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df.isnull().sum()
# Out:
# age       0
# status    1
# dtype: int64

# %%
handle = df['status'].median()

# %%
handle
# Out:
# 0.0

# %%
df.status = df.status.fillna(handle)

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     0.0
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df['status'].value_counts()
# Out:
# 0.0    11
# 1.0     9
# Name: status, dtype: int64

# %%
x = df[['age']]

# %%
x
# Out:
#     age
# 0    21
# 1    33
# 2    24
# 3    28
# 4    17
# 5    33
# 6    23
# 7    30
# 8    29
# 9    22
# 10   26
# 11   20
# 12   22
# 13   24
# 14   34
# 15   29
# 16   16
# 17   18
# 18   26
# 19   25

# %%
y = df['status']

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     0.0
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
y
# Out:
# 0     0.0
# 1     1.0
# 2     0.0
# 3     1.0
# 4     0.0
# 5     1.0
# 6     0.0
# 7     0.0
# 8     1.0
# 9     0.0
# 10    1.0
# 11    0.0
# 12    0.0
# 13    0.0
# 14    1.0
# 15    1.0
# 16    0.0
# 17    0.0
# 18    1.0
# 19    1.0
# Name: status, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30,random_state=1)

# %%
xtest
# Out:
#     age
# 3    28
# 16   16
# 6    23
# 10   26
# 2    24
# 14   34

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([1., 0., 0., 0., 0., 1.])

# %%
model.score(xtest,ytest)
# Out:
# 0.8333333333333334

# %%
model.predict_log_proba(xtest)
# Out:
# array([[-1.24837581, -0.3382325 ],
#        [-0.00975069, -4.63528891],
#        [-0.22113243, -1.61752309],
#        [-0.68693148, -0.69940176],
#        [-0.33113871, -1.26622258],
#        [-3.70294385, -0.02495977]])
